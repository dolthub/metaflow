# %%
# !cat iris_demo.py
# Out:
# import logging
#
# logger = logging.getLogger()
# logger.setLevel(logging.WARNING)
#
# from metaflow import FlowSpec, step, DoltDT
# import pandas as pd
# import pickle
# from sklearn import tree
#
# class DoltMLDemoFlow(FlowSpec):
#     @step
#     def start(self):
#         # Start by getting original dataset
#         with DoltDT(run=self, database='iris-test') as dolt:
#             self.test_set = dolt.read_table('iris-test')
#
#         self.next(self.predict)
#
#     @step
#     def predict(self):
#         with DoltDT(run=self, database='iris-model-results') as dolt:
#             self.model = pickle.load(open('model.p', 'rb'))
#             self.model_type = 'Decision Tree'
#
#             samples = self.test_set['sample']
#             y_true = self.test_set['species']
#             y_true = y_true.rename('labels')
#
#             test = self.test_set.drop(columns=['species', 'sample'])
#             predictions = pd.Series(self.model.predict(test))
#             predictions = predictions.rename('predictions')
#
#             self.result = pd.concat([samples, y_true, predictions], axis=1)
#
#             dolt.write_table(table_name='result', df=self.result, pks=['sample'])
#
#         self.next(self.end)
#
#     @step
#     def end(self):
#         pass
#
# if __name__ == '__main__':
#     DoltMLDemoFlow()

# %%
# !poetry run python3 iris_demo.py run
# Out:
# Metaflow 2.2.5.post24+git1f18147 executing DoltMLDemoFlow for user:max-hoffman
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# 2021-01-17 19:04:21.920 Workflow starting (run-id 1610939061912544):
# 2021-01-17 19:04:21.929 [1610939061912544/start/1 (pid 31821)] Task is starting.
# 2021-01-17 19:04:23.494 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:23 doltpy.core.dolt INFO     Creating engine for Dolt SQL Server instance running on 127.0.0.1:3306
# 2021-01-17 19:04:23.554 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:23 doltpy.core.dolt INFO     Creating engine for Dolt SQL Server instance running on 127.0.0.1:3306
# 2021-01-17 19:04:23.840 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:23 doltpy.core.dolt INFO     * master                                        	cnt6q9n22svhdvb1n3g90kk43k3b9aol
# 2021-01-17 19:04:24.032 [1610939061912544/start/1 (pid 31821)]
# 2021-01-17 19:04:24.032 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.dolt INFO
# 2021-01-17 19:04:24.221 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.write.write INFO     No import mode specified, table exists, using "update"
# 2021-01-17 19:04:24.221 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.write.write INFO     Importing to table metadata in dolt directory located in /Users/max-hoffman/Documents/sandbox/dolt/metaflow/dolt-demos/1-reproducibility-1-dolthub, import mode update
# 2021-01-17 19:04:24.320 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.dolt INFO     Rows Processed: 1, Additions: 1, Modifications: 0, Had No Effect: 0
# 2021-01-17 19:04:24.368 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.dolt INFO
# 2021-01-17 19:04:24.479 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.dolt INFO     commit dtum0b36m7lopbb45pdja6kaenprgtfr
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)] Author: Max Hoffman <maximilian.wolfgang1@gmail.com>
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)] Date:   Sun Jan 17 19:04:24 -0800 2021
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)]
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)] 	DoltMLDemoFlow/1610939061912544/start/1
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)]
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)]
# 2021-01-17 19:04:24.491 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.system_helpers INFO     Before exiting cleaning up child processes
# 2021-01-17 19:04:24.499 [1610939061912544/start/1 (pid 31821)] 01-17 19:04:24 doltpy.core.system_helpers INFO     No processes to clean up, exiting
# 2021-01-17 19:04:24.672 [1610939061912544/start/1 (pid 31821)] Task finished successfully.
# 2021-01-17 19:04:24.680 [1610939061912544/predict/2 (pid 31855)] Task is starting.
# 2021-01-17 19:04:25.930 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:25 doltpy.core.dolt INFO     Creating engine for Dolt SQL Server instance running on 127.0.0.1:3306
# 2021-01-17 19:04:25.961 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:25 doltpy.core.dolt INFO     Creating engine for Dolt SQL Server instance running on 127.0.0.1:3306
# 2021-01-17 19:04:26.035 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO     * master                                        	4do9ospeovkuaenoqkd963fedaipr9en
# 2021-01-17 19:04:26.149 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.149 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.write.write INFO     No import mode specified, table exists, using "create"
# 2021-01-17 19:04:26.244 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.write.write INFO     Importing to table result in dolt directory located in iris-model-results, import mode create
# 2021-01-17 19:04:26.244 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO     Rows Processed: 34, Additions: 34, Modifications: 0, Had No Effect: 0
# 2021-01-17 19:04:26.330 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO
# 2021-01-17 19:04:26.430 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO     commit 25r59288gk68cujjk9kdr2s2a77f8okd
# 2021-01-17 19:04:26.573 [1610939061912544/predict/2 (pid 31855)] Author: Max Hoffman <maximilian.wolfgang1@gmail.com>
# 2021-01-17 19:04:26.573 [1610939061912544/predict/2 (pid 31855)] Date:   Sun Jan 17 19:04:26 -0800 2021
# 2021-01-17 19:04:26.573 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.574 [1610939061912544/predict/2 (pid 31855)] 	DoltMLDemoFlow/1610939061912544/predict/2
# 2021-01-17 19:04:26.574 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.574 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.574 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.write.write INFO     No import mode specified, table exists, using "update"
# 2021-01-17 19:04:26.660 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.write.write INFO     Importing to table metadata in dolt directory located in /Users/max-hoffman/Documents/sandbox/dolt/metaflow/dolt-demos/1-reproducibility-1-dolthub, import mode update
# 2021-01-17 19:04:26.660 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO     Rows Processed: 1, Additions: 1, Modifications: 0, Had No Effect: 0
# 2021-01-17 19:04:26.707 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO
# 2021-01-17 19:04:26.811 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.dolt INFO     commit 56i3ss99v17h7sqe0icf0un5li7fnp2m
# 2021-01-17 19:04:26.822 [1610939061912544/predict/2 (pid 31855)] Author: Max Hoffman <maximilian.wolfgang1@gmail.com>
# 2021-01-17 19:04:26.822 [1610939061912544/predict/2 (pid 31855)] Date:   Sun Jan 17 19:04:26 -0800 2021
# 2021-01-17 19:04:26.822 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.823 [1610939061912544/predict/2 (pid 31855)] 	DoltMLDemoFlow/1610939061912544/predict/2
# 2021-01-17 19:04:26.823 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.823 [1610939061912544/predict/2 (pid 31855)]
# 2021-01-17 19:04:26.823 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.system_helpers INFO     Before exiting cleaning up child processes
# 2021-01-17 19:04:26.832 [1610939061912544/predict/2 (pid 31855)] 01-17 19:04:26 doltpy.core.system_helpers INFO     No processes to clean up, exiting
# 2021-01-17 19:04:27.006 [1610939061912544/predict/2 (pid 31855)] Task finished successfully.
# 2021-01-17 19:04:27.014 [1610939061912544/end/3 (pid 31895)] Task is starting.
# 2021-01-17 19:04:28.248 [1610939061912544/end/3 (pid 31895)] 01-17 19:04:28 doltpy.core.system_helpers INFO     Before exiting cleaning up child processes
# 2021-01-17 19:04:28.256 [1610939061912544/end/3 (pid 31895)] 01-17 19:04:28 doltpy.core.system_helpers INFO     No processes to clean up, exiting
# 2021-01-17 19:04:28.425 [1610939061912544/end/3 (pid 31895)] Task finished successfully.
# 2021-01-17 19:04:28.425 Done!
# 01-17 19:04:28 doltpy.core.system_helpers INFO     Before exiting cleaning up child processes
# 01-17 19:04:28 doltpy.core.system_helpers INFO     No processes to clean up, exiting

# %%
# !dolt sql -q "SELECT `flow_name`, `run_id` from metadata;"
# Out:
# +----------------+------------------+
# | flow_name      | run_id           |
# +----------------+------------------+
# | DoltMLDemoFlow | 1610920919008498 |
# | DoltMLDemoFlow | 1610920919008498 |
# | DoltMLDemoFlow | 1610939061912544 |
# | DoltMLDemoFlow | 1610939061912544 |
# +----------------+------------------+

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.WARNING)

from metaflow.datatools.dolt import DoltRun

d = DoltRun(flow_name="DoltMLDemoFlow", run_id="1610939061912544")

# %%
d.reads[0].data
# Out:
#    sample sepal_length sepal_width petal_length petal_width     species
# 0       3          4.7         3.2          1.3         0.2      setosa
# 1       5            5         3.6          1.4         0.2      setosa
# 2      10          4.9         3.1          1.5         0.1      setosa
# 3      29          5.2         3.4          1.4         0.2      setosa
# 4      32          5.4         3.4          1.5         0.4      setosa
# 5      35          4.9         3.1          1.5         0.1      setosa
# 6      40          5.1         3.4          1.5         0.2      setosa
# 7      42          4.5         2.3          1.3         0.3      setosa
# 8      51            7         3.2          4.7         1.4  versicolor
# 9      58          4.9         2.4          3.3           1  versicolor
# 10     60          5.2         2.7          3.9         1.4  versicolor
# 11     62          5.9           3          4.2         1.5  versicolor
# 12     63            6         2.2            4           1  versicolor
# 13     65          5.6         2.9          3.6         1.3  versicolor
# 14     67          5.6           3          4.5         1.5  versicolor
# 15     69          6.2         2.2          4.5         1.5  versicolor
# 16     70          5.6         2.5          3.9         1.1  versicolor
# 17     73          6.3         2.5          4.9         1.5  versicolor
# 18     74          6.1         2.8          4.7         1.2  versicolor
# 19     75          6.4         2.9          4.3         1.3  versicolor
# 20    133          6.4         2.8          5.6         2.2   virginica
# 21    136          7.7           3          6.1         2.3   virginica
# 22    143          5.8         2.7          5.1         1.9   virginica
# 23    147          6.3         2.5            5         1.9   virginica
# 24     79            6         2.9          4.5         1.5  versicolor
# 25     89          5.6           3          4.1         1.3  versicolor
# 26     91          5.5         2.6          4.4         1.2  versicolor
# 27    104          6.3         2.9          5.6         1.8   virginica
# 28    115          5.8         2.8          5.1         2.4   virginica
# 29    121          6.9         3.2          5.7         2.3   virginica
# 30    122          5.6         2.8          4.9           2   virginica
# 31    123          7.7         2.8          6.7           2   virginica
# 32    130          7.2           3          5.8         1.6   virginica
# 33    131          7.4         2.8          6.1         1.9   virginica

# %%
d.writes[0].data
# Out:
#    sample      labels predictions
# 0       3      setosa      setosa
# 1       5      setosa      setosa
# 2      10      setosa      setosa
# 3      29      setosa      setosa
# 4      32      setosa      setosa
# 5      35      setosa      setosa
# 6      40      setosa      setosa
# 7      42      setosa      setosa
# 8      51  versicolor  versicolor
# 9      58  versicolor  versicolor
# 10     60  versicolor  versicolor
# 11     62  versicolor  versicolor
# 12     63  versicolor  versicolor
# 13     65  versicolor  versicolor
# 14     67  versicolor  versicolor
# 15     69  versicolor  versicolor
# 16     70  versicolor  versicolor
# 17     73  versicolor  versicolor
# 18     74  versicolor  versicolor
# 19     75  versicolor  versicolor
# 20     79  versicolor  versicolor
# 21     89  versicolor  versicolor
# 22     91  versicolor  versicolor
# 23    104   virginica   virginica
# 24    115   virginica   virginica
# 25    121   virginica   virginica
# 26    122   virginica   virginica
# 27    123   virginica   virginica
# 28    130   virginica  versicolor
# 29    131   virginica   virginica
# 30    133   virginica   virginica
# 31    136   virginica   virginica
# 32    143   virginica   virginica
# 33    147   virginica   virginica
